# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error

# %%
data = pd.read_csv("/content/IMDb Movies India.csv" ,encoding='latin-1')
data
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                             #Homecoming  (2021)   90 min   Drama, Musical
# 3                                 #Yaaram  (2019)  110 min  Comedy, Romance
# 4                       ...And Once Again  (2010)  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga  (1988)      NaN           Action
# 15505                               Zulmi  (1999)  129 min    Action, Drama
# 15506                           Zulmi Raj  (2005)      NaN           Action
# 15507                       Zulmi Shikari  (1988)      NaN           Action
# 15508                        Zulm-O-Sitam  (1998)  130 min    Action, Drama
#
# ...

# %%
#data['Actors'] = data['Actor 1'] +" , " +  data['Actor 2'] + " , " + data['Actor 3']

# %%
data.drop(columns=['Name' , 'Year' , 'Duration', 'Votes'],inplace=True)

# %%
data
# Out:
#                  Genre  Rating            Director           Actor 1  \
# 0                Drama     NaN       J.S. Randhawa          Manmauji
# 1                Drama     7.0       Gaurav Bakshi      Rasika Dugal
# 2       Drama, Musical     NaN  Soumyajit Majumdar      Sayani Gupta
# 3      Comedy, Romance     4.4          Ovais Khan           Prateik
# 4                Drama     NaN        Amol Palekar      Rajat Kapoor
# ...                ...     ...                 ...               ...
# 15504           Action     4.6       Mahendra Shah  Naseeruddin Shah
# 15505    Action, Drama     4.5          Kuku Kohli      Akshay Kumar
# 15506           Action     NaN          Kiran Thej   Sangeeta Tiwari
# 15507           Action     NaN                 NaN               NaN
# 15508    Action, Drama     6.2        K.C. Bokadia        Dharmendra
#
#                   Actor 2          Actor 3
# 0                  Birbal  Rajendra Bhatia
# 1          Vivek Ghamande    Arvind Jangid
# ...

# %%
data.dropna(inplace = True)

# %%
Y = data['Rating']
features = ['Genre' , 'Director' , 'Actor 1' , 'Actor 2' , 'Actor 3']
X = data[features]

# %%
one_hot_encoded_data = pd.get_dummies(X, columns = ['Genre', 'Director' , 'Actor 1' , 'Actor 2' , 'Actor 3'])

# %%
one_hot_encoded_data.head(5)
# Out:
#    Genre_Action  Genre_Action, Adventure  Genre_Action, Adventure, Biography  \
# 1             0                        0                                   0
# 3             0                        0                                   0
# 5             0                        0                                   0
# 6             0                        0                                   0
# 8             0                        0                                   0
#
#    Genre_Action, Adventure, Comedy  Genre_Action, Adventure, Crime  \
# 1                                0                               0
# 3                                0                               0
# 5                                0                               0
# 6                                0                               0
# 8                                0                               0
#
#    Genre_Action, Adventure, Drama  Genre_Action, Adventure, Family  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(one_hot_encoded_data, Y, test_size = 0.2 , random_state=1)

# %%
model = DecisionTreeRegressor()
model.fit(X_train, y_train)
preds_val = model.predict(X_test)
mae = mean_absolute_error(y_test, preds_val)

# %%
print("The model is trained with mean squared error of " , mae)
# Out:
# The model is trained with mean squared error of  1.1398148148148148

# %%
dataF = {'Actual': y_test,
        'Predicted': preds_val}
pd.DataFrame(dataF)
# Out:
#        Actual  Predicted
# 5159      7.0        6.8
# 12688     6.8        7.1
# 14355     4.1        5.8
# 2584      2.6        6.9
# 7118      6.9        2.3
# ...       ...        ...
# 6398      5.6        5.8
# 307       5.6        6.6
# 15252     4.4        6.1
# 14602     5.5        4.9
# 5545      6.2        4.7
#
# [1512 rows x 2 columns]
